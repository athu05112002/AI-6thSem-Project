# %% [markdown]
# ##### Author : Atharva Kulkarni
# ##### Author : Sarthak Goyal

# %%
from turtle import ht
import cv2  # pip install opencv-contrib-python
import numpy as np
import mediapipe as mp  # pip install mediapipe
import pyautogui    # pip install PyautoGUI
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
points = Image(url="hand_landmarks.png")
points
# img=cv2.imread("hand_landmarks.png")
# RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plt.imshow(img)
# Out:
# <img src="hand_landmarks.png"/>

# %%
cap = cv2.VideoCapture(0)   # capture video '0' one cam
hand_detector = mp.solutions.hands.Hands()  # detect hand
drawing_utils = mp.solutions.drawing_utils
screen_width, screen_height = pyautogui.size()
index_y = 0

# %%
'''Smoothen the movement of mouse to stop at the exact position of,
   our hand movement without any shake in the movement of the mouse'''
smoothening = 9
plocx, plocy = 0, 0
clocx, clocy = 0, 0

# %%
while True:
    _, frame = cap.read()   # read data from cap
    '''Flip the frame or screen since the camera shows the mirror image,
       of our hand and moves in opposite direction so we need to flip the screen'''
    frame = cv2.flip(frame, 1)
     # shape gives frame height and width using shape 
    frame_height, frame_width, _ = frame.shape
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # detect on rgb frame color
    output = hand_detector.process(rgb_frame)
    hands = output.multi_hand_landmarks # hand landmark
    
    if hands:
        for hand in hands:
            drawing_utils.draw_landmarks(frame, hand)   # see landmarks on frame
            # we use our index finger tip move the mouse 
            landmarks = hand.landmark
            
            for id, landmark in enumerate(landmarks):   # add counter
                # show the landmarks on kernel in x and y axis
                # x and y axis is multiplies by the height and width to get the x and y axis on the frames
                x = int(landmark.x*frame_width)
                y = int(landmark.y*frame_height)
                # print(x,y)
                # Index finger tip point number is 8
                # and draw a boundary to the point a circle
                if id == 8:
                    cv2.circle(img=frame, center=(x,y), radius=15, color=(0, 255, 255))
                    # pyautogui.moveTo(x,y)
                    index_x = (screen_width/frame_width)*x
                    index_y = (screen_height/frame_height)*y
                    # co-ordinates need to be changed 
                    # smoothining varies with the change in the smoothening factor
                    clocx = plocx + (index_x - plocx) /smoothening
                    clocy = plocy + (index_y - plocy) /smoothening
                    pyautogui.moveTo(clocx, clocy)
                    plocx, plocy = clocx, clocy
                
                # thumb tip point number is 4

                if id == 12:
                    cv2.circle(img=frame, center=(x,y), radius=15, color=(0, 255, 255))
                    thumb_x = (screen_width/frame_width)*x
                    thumb_y = (screen_height/frame_height)*y
                    print('distance : ', abs(index_y - thumb_y))
                    if abs(index_y - thumb_y) < 70:
                        print('click')
                        pyautogui.click()
                        pyautogui.sleep(1)
    cv2.imshow('Virtual Mouse', frame)  # show image
    cv2.waitKey(1)  # waits for key infinitely
# Out:
# distance :  29.25
# click
# distance :  42.75
# click
# distance :  371.25
# distance :  411.75
# distance :  443.25
# distance :  456.75
# distance :  477.0
# distance :  447.75
# distance :  490.5
# distance :  117.0
# distance :  445.5
# distance :  326.25
# distance :  409.5
# distance :  508.5
# distance :  553.5
# distance :  411.75
# distance :  135.0
# distance :  382.5
# distance :  371.25
# distance :  369.0
# distance :  373.5
# distance :  333.0
# distance :  315.0
# distance :  67.5
# click
# distance :  72.0
# distance :  85.5
# distance :  92.25
# distance :  162.0
# distance :  114.75
# distance :  83.25
# distance :  130.5
# distance :  135.0
# distance :  45.0
# click
# distance :  373.5
# distance :  18.0
# click
# distance :  380.25
# distance :  387.0
# distance :  450.0
# distance :  450.0
# distance :  45.0
# click
# distance :  470.25
# distance :  447.75
# distance :  447.75
# distance :  398.25
# distance :  396.0
# distance :  391.5
# distance :  432.0
# distance :  310.5
# distance :  20.25
# click
# distance :  317.25
# distance :  490.5
# distance :  418.5
# distance :  463.5
# distance :  391.5
# distance :  418.5
# distance :  434.25
# distance :  420.75
# distance :  429.75
# distance :  409.5
# distance :  402.75
# distance :  371.25
# distance :  335.25
# distance :  285.75
# distance :  380.25
# distance :  294.75
# distance :  418.5
# distance :  328.5
# distance :  276.75
# distance :  276.75
# distance :  191.25
# distance :  436.5
# distance :  461.25
# distance :  418.5
# distance :  447.75
# distance :  407.25
# distance :  414.0
# distance :  447.75
# distance :  463.5
# distance :  402.75
# distance :  438.75
# distance :  405.0
# distance :  472.5
# distance :  445.5
# distance :  490.5
# distance :  483.75
# distance :  528.75
# distance :  522.0
# distance :  508.5
# distance :  490.5
# distance :  479.25
# distance :  378.0
# distance :  436.5
# distance :  461.25
# distance :  450.0
# distance :  405.0
# distance :  416.25
# distance :  418.5
# distance :  420.75
# distance :  418.5
# distance :  294.75
# distance :  420.75
# distance :  391.5
# distance :  432.0
# distance :  369.0
# distance :  418.5
# distance :  420.75
# distance :  409.5
# distance :  423.0
# distance :  423.0
# distance :  425.25
# distance :  429.75
# distance :  432.0
# distance :  416.25
# distance :  425.25
# distance :  418.5
# distance :  429.75
# distance :  425.25
# distance :  393.75
# distance :  423.0
# distance :  427.5
# distance :  423.0
# distance :  427.5
# distance :  432.0
# distance :  434.25
# distance :  429.75
# distance :  425.25
# distance :  438.75
# distance :  438.75
# distance :  432.0
# distance :  425.25
# distance :  423.0
# distance :  499.5
# distance :  526.5
# distance :  533.25
# distance :  339.75
# distance :  94.5
# distance :  81.0
# distance :  33.75
# click
# distance :  49.5
# click
# distance :  42.75
# click
# distance :  22.5
# click
# distance :  13.5
# click
# distance :  42.75
# click
# distance :  24.75
# click
# distance :  18.0
# click
# distance :  24.75
# click
# distance :  24.75
# click
# distance :  36.0
# click
# distance :  551.25
# distance :  33.75
# click
# distance :  18.0
# click
# distance :  11.25
# click
# distance :  13.5
# click
# distance :  13.5
# click
# distance :  42.75
# click
# distance :  38.25
# click
# distance :  29.25
# click
# distance :  60.75
# click
# distance :  63.0
# click
# distance :  27.0
# click
# distance :  6.75
# click
# distance :  2.25
# click
# distance :  580.5
# distance :  240.75
# distance :  337.5
# distance :  42.75
# click
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ATHARVA\Downloads\Hand-Controlled-AI-Virtual-Mouse-master\Hand-Controlled-AI-Virtual-Mouse-master\vitual_mouse.ipynb Cell 6 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/ATHARVA/Downloads/Hand-Controlled-AI-Virtual-Mouse-master/Hand-Controlled-AI-Virtual-Mouse-master/vitual_mouse.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> frame_height, frame_width, _ = frame.shape
#       <a href='vscode-notebook-cell:/c%3A/Users/ATHARVA/Downloads/Hand-Controlled-AI-Virtual-Mouse-master/Hand-Controlled-AI-Virtual-Mouse-master/vitual_mouse.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # detect on rgb frame color
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ATHARVA/Downloads/Hand-Controlled-AI-Virtual-Mouse-master/Hand-Controlled-AI-Virtual-Mouse-master/vitual_mouse.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> output = hand_detector.process(rgb_frame)
#      <a href='vscode-notebook-cell:/c%3A/Users/ATHARVA/Downloads/Hand-Controlled-AI-Virtual-Mouse-master/Hand-Controlled-AI-Virtual-Mouse-master/vitual_mouse.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a> hands = output.multi_hand_landmarks # hand landmark
#      <a href='vscode-notebook-cell:/c%3A/Users/ATHARVA/Downloads/Hand-Controlled-AI-Virtual-Mouse-master/Hand-Controlled-AI-Virtual-Mouse-master/vitual_mouse.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> if hands:
#
# File c:\Users\ATHARVA\AppData\Local\Programs\Python\Python310\lib\site-packages\mediapipe\python\solutions\hands.py:153, in Hands.process(self, image)
#     132 def process(self, image: np.ndarray) -> NamedTuple:
#     133   """Processes an RGB image and returns the hand landmarks and handedness of each detected hand.
#     134
#     135   Args:
#    (...)
#     150          right hand) of the detected hand.
#     151   """
# --> 153   return super().process(input_data={'image': image})
#
# File c:\Users\ATHARVA\AppData\Local\Programs\Python\Python310\lib\site-packages\mediapipe\python\solution_base.py:365, in SolutionBase.process(self, input_data)
#     359   else:
#     360     self._graph.add_packet_to_input_stream(
#     361         stream=stream_name,
#     362         packet=self._make_packet(input_stream_type,
#     363                                  data).at(self._simulated_timestamp))
# --> 365 self._graph.wait_until_idle()
#     366 # Create a NamedTuple object where the field names are mapping to the graph
#     367 # output stream names.
#     368 solution_outputs = collections.namedtuple(
#     369     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
